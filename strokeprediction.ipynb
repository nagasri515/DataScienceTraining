# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.size
# Out:
# 61320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
df['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df['age'].unique()
# Out:
# array([6.70e+01, 6.10e+01, 8.00e+01, 4.90e+01, 7.90e+01, 8.10e+01,
#        7.40e+01, 6.90e+01, 5.90e+01, 7.80e+01, 5.40e+01, 5.00e+01,
#        6.40e+01, 7.50e+01, 6.00e+01, 5.70e+01, 7.10e+01, 5.20e+01,
#        8.20e+01, 6.50e+01, 5.80e+01, 4.20e+01, 4.80e+01, 7.20e+01,
#        6.30e+01, 7.60e+01, 3.90e+01, 7.70e+01, 7.30e+01, 5.60e+01,
#        4.50e+01, 7.00e+01, 6.60e+01, 5.10e+01, 4.30e+01, 6.80e+01,
#        4.70e+01, 5.30e+01, 3.80e+01, 5.50e+01, 1.32e+00, 4.60e+01,
#        3.20e+01, 1.40e+01, 3.00e+00, 8.00e+00, 3.70e+01, 4.00e+01,
#        3.50e+01, 2.00e+01, 4.40e+01, 2.50e+01, 2.70e+01, 2.30e+01,
#        1.70e+01, 1.30e+01, 4.00e+00, 1.60e+01, 2.20e+01, 3.00e+01,
#        2.90e+01, 1.10e+01, 2.10e+01, 1.80e+01, 3.30e+01, 2.40e+01,
#        3.40e+01, 3.60e+01, 6.40e-01, 4.10e+01, 8.80e-01, 5.00e+00,
#        2.60e+01, 3.10e+01, 7.00e+00, 1.20e+01, 6.20e+01, 2.00e+00,
#        9.00e+00, 1.50e+01, 2.80e+01, 1.00e+01, 1.80e+00, 3.20e-01,
# ...

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
df['heart_disease'].value_counts()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df["bmi"].fillna(df["bmi"].mean(), inplace=True)
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df['age'].max()
# Out:
# 82.0

# %%
interval=[0,12,19,30,60,90]
categories=['child','teenage','young_adult','middle_aged','senior_citizen']

# %% [markdown]
# ### Discretization

# %%
df['age_category']=pd.cut(df['age'], bins=interval, labels=categories)

# %%
df[['age_category','age']]
# Out:
#         age_category   age
# 0     senior_citizen  67.0
# 1     senior_citizen  61.0
# 2     senior_citizen  80.0
# 3        middle_aged  49.0
# 4     senior_citizen  79.0
# ...              ...   ...
# 5105  senior_citizen  80.0
# 5106  senior_citizen  81.0
# 5107     middle_aged  35.0
# 5108     middle_aged  51.0
# 5109     middle_aged  44.0
#
# [5110 rows x 2 columns]

# %%
df['age_category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
### import from sklearn library
from sklearn.preprocessing import LabelEncoder

### Call the function
le = LabelEncoder()

### fit_transform
df['gender'] = le.fit_transform(df['gender'])

df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046       1  67.0             0              1          Yes
# 1     51676       0  61.0             0              0          Yes
# 2     31112       1  80.0             0              1          Yes
# 3     60182       0  49.0             0              0          Yes
# 4      1665       0  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234       0  80.0             1              0          Yes
# 5106  44873       0  81.0             0              0          Yes
# 5107  19723       0  35.0             0              0          Yes
# 5108  37544       1  51.0             0              0          Yes
# 5109  44679       0  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
### import from sklearn library
from sklearn.preprocessing import LabelEncoder

### Call the function
le = LabelEncoder()

### fit_transform
df['Residence_type'] = le.fit_transform(df['Residence_type'])

df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046       1  67.0             0              1          Yes
# 1     51676       0  61.0             0              0          Yes
# 2     31112       1  80.0             0              1          Yes
# 3     60182       0  49.0             0              0          Yes
# 4      1665       0  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234       0  80.0             1              0          Yes
# 5106  44873       0  81.0             0              0          Yes
# 5107  19723       0  35.0             0              0          Yes
# 5108  37544       1  51.0             0              0          Yes
# 5109  44679       0  44.0             0              0          Yes
#
#           work_type  Residence_type  avg_glucose_level        bmi  \
# 0           Private               1             228.69  36.600000
# ...

# %%
df = df.drop('age_category', axis=1)

# %%
df = df.drop('id', axis=1)

# %%
### import from sklearn library
from sklearn.preprocessing import LabelEncoder

### Call the function
le = LabelEncoder()

### fit_transform
df['smoking_status'] = le.fit_transform(df['smoking_status'])
df['work_type'] = le.fit_transform(df['work_type'])
df['ever_married'] = le.fit_transform(df['ever_married'])
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.boxplot(x = df['age'])
plt.show()

# %%
sns.boxplot(x = df['bmi'])
plt.show()

# %%
sns.boxplot(x = df['avg_glucose_level'])
plt.show()

# %%
from feature_engine.outliers import Winsorizer

win = Winsorizer(capping_method = 'iqr' , tail = 'both',
                 fold = 1.5, variables=['avg_glucose_level'])

df_win = win.fit_transform(df[['avg_glucose_level']])

df_win
# Out:
#       avg_glucose_level
# 0              169.3575
# 1              169.3575
# 2              105.9200
# 3              169.3575
# 4              169.3575
# ...                 ...
# 5105            83.7500
# 5106           125.2000
# 5107            82.9900
# 5108           166.2900
# 5109            85.2800
#
# [5110 rows x 1 columns]

# %%
print(win.left_tail_caps_, win.right_tail_caps_)
# Out:
# {'avg_glucose_level': 21.977500000000006} {'avg_glucose_level': 169.35750000000002}

# %%
sns.boxplot(x = df_win['avg_glucose_level'])
plt.show()

# %%
from feature_engine.outliers import Winsorizer

win_1 = Winsorizer(capping_method = 'iqr' , tail = 'both',
                 fold = 1.5, variables=['bmi'])

df_win_1 = win_1.fit_transform(df[['bmi']])

df_win_1
# Out:
#             bmi
# 0     36.600000
# 1     28.893237
# 2     32.500000
# 3     34.400000
# 4     24.000000
# ...         ...
# 5105  28.893237
# 5106  40.000000
# 5107  30.600000
# 5108  25.600000
# 5109  26.200000
#
# [5110 rows x 1 columns]

# %%
print(win_1.left_tail_caps_, win_1.right_tail_caps_)
# Out:
# {'bmi': 10.300000000000006} {'bmi': 46.29999999999999}

# %%
sns.boxplot(x = df_win_1['bmi'])
plt.show()

# %%
skew_values = df[['age', 'avg_glucose_level', 'bmi']].skew()
print(skew_values)
# Out:
# age                 -0.137059
# avg_glucose_level    1.572284
# bmi                  1.076716
# dtype: float64
