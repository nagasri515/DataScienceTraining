# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data load

# %%
df =pd.read_csv(r'C:\Users\nagasri15\Downloads\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### About this file
#
# Relevant Information:
# Several constraints were placed on the selection of these instances from
# a larger database. In particular, all patients here are females at
# least 21 years old of Pima Indian heritage. ADAP is an adaptive learning
# routine that generates and executes digital analogs of perceptron-like
# devices. It is a unique algorithm; see the paper for details.

# %% [markdown]
# ### About Dataset
# Number of Instances: 768
#
# Number of Attributes: 8 plus class
#
# For Each Attribute: (all numeric-valued)
#
# 1.Number of times pregnant
#
# 2.Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# 3.Diastolic blood pressure (mm Hg)
#
# 4.Triceps skin fold thickness (mm)
#
# 5.2-Hour serum insulin (mu U/ml)
#
# 6.Body mass index (weight in kg/(height in m)^2)
#
# 7.Diabetes pedigree function
#
# 8.Age (years)
#
# 9.Class variable (0 or 1)
#
# -->Missing Attribute Values: Yes
#
# -->Class Distribution: (class value 1 is interpreted as "tested positive for
# diabetes")
#
# -->Class Value Number of instances
# 0 : 500
# 1 : 268

# %%
df.shape
# Out:
# (768, 9)

# %%
df.size
# Out:
# 6912

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# ### EDA

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### Graphs using matplot

# %% [markdown]
# ### Histogram on Univarient

# %%
plt.hist(df['Outcome'])
plt.xlabel('Outcome')
plt.ylabel('Count/Frequency')
plt.title('Histogram of Outcome')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.boxplot(df['Outcome'])
plt.title("BoxPlot of Outcome")
plt.show()

# %% [markdown]
# ### Scatter plot by Bivarient

# %%
plt.scatter(df['Outcome'],df['BMI'])
plt.show()

# %% [markdown]
# ### Line plot by Bivarient

# %%
plt.plot(df['BMI'],df['Outcome'])
plt.show()

# %% [markdown]
# ### Graphs using Seaborn

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.displot(df["Outcome"],bins=10,kde=True)

# %%
sns.displot(df["Outcome"],bins=10)

# %%
sns.displot(df["Outcome"],bins=20,kde=True)

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(y=df["Outcome"])
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(x=df["Outcome"],y=df["BMI"])
plt.show()

# %%
sns.relplot(x=df["Outcome"],y=df["BloodPressure"],data=df)
plt.show()

# %% [markdown]
# ### Joint plot

# %%
sns.jointplot(x="Outcome",y="BMI",data=df)
plt.show()

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### Duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Outliers

# %%
sns.boxplot(x = df['Outcome'])
plt.show()
